# %%
# !pip install rembg
from rembg import remove
import matplotlib.pyplot as plt
# !pip install pillow
from PIL import Image

# %%
import requests
# Online Method
url = 'https://i.pinimg.com/736x/cc/6c/83/cc6c83caf8f25ce60dba6b577a8bd9ab.jpg'
im = Image.open(requests.get(url,stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=665x1000>

# %%
# Offline method
# url = ''
# Image.open(url)

# %%
output = remove(im)

# %%
plt.imshow(output)
